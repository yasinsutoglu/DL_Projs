# %% [markdown]
# # Emotion Classification with GloVe and LSTM

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import zipfile
import os
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %% [markdown]
# ##Data Prep

# %%
train_df = pd.read_csv('../emotion_dataset/train.txt', sep=';', header=None, names=['text', 'label'])
val_df = pd.read_csv('../emotion_dataset/val.txt', sep=';', header=None, names=['text', 'label'])
test_df = pd.read_csv('../emotion_dataset/test.txt', sep=';', header=None, names=['text', 'label'])

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text(text):
    
    text = re.sub(r'[^\w\s]', '', text)  # punctuations
    text = text.lower()  # lower case
    text = re.sub(r'\d+', '', text)  # numbers
    text = ' '.join([word for word in text.split() if word not in stop_words])  # Stopwords
    text = re.sub(r'\s+', ' ', text).strip()  # space
    
    return text

train_df['text'] = train_df['text'].apply(clean_text)
val_df['text'] = val_df['text'].apply(clean_text)
test_df['text'] = test_df['text'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
label_to_int = {'joy': 0, 'sadness': 1, 'anger': 2, 'fear': 3, 'love': 4, 'surprise': 5}

train_df['label'] = train_df['label'].map(label_to_int)
val_df['label'] = val_df['label'].map(label_to_int)
test_df['label'] = test_df['label'].map(label_to_int)

# %%
max_words = 10000

tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(train_df['text'])

X_train = tokenizer.texts_to_sequences(train_df['text'])
X_val = tokenizer.texts_to_sequences(val_df['text'])
X_test = tokenizer.texts_to_sequences(test_df['text'])

max_len = 100
X_train = pad_sequences(X_train, maxlen=max_len)
X_val = pad_sequences(X_val, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
y_train = train_df['label']
y_val = val_df['label']
y_test = test_df['label']

# %% [markdown]
# ## Download GloVe Vectors
#
# Use => https://nlp.stanford.edu/projects/glove/
#
# OR
#
# Use=> !wget http://nlp.stanford.edu/data/glove.6B.zip  &&& !unzip glove.6B.zip

# %%
# glove_zip_path = "/content/drive/MyDrive/Colab Notebooks/glove.6B.zip"
# with zipfile.ZipFile(glove_zip_path, 'r') as zip_ref:
#     zip_ref.extractall('/content/glove')

# %%
glove_file_path = '../glove6B/glove.6B.200d.txt'

# %% [markdown]
# ## Load GloVe Vectors and Create Embedding Matrix

# %%
def load_glove_embeddings(file_path):
    
    embeddings_index = {}
    
    with open(file_path, encoding="utf8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            weights = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = weights
            
    return embeddings_index


embeddings_index = load_glove_embeddings(glove_file_path)

list(embeddings_index.items())[:10]
# Out:
# [('the',
#   array([-7.1549e-02,  9.3459e-02,  2.3738e-02, -9.0339e-02,  5.6123e-02,
#           3.2547e-01, -3.9796e-01, -9.2139e-02,  6.1181e-02, -1.8950e-01,
#           1.3061e-01,  1.4349e-01,  1.1479e-02,  3.8158e-01,  5.4030e-01,
#          -1.4088e-01,  2.4315e-01,  2.3036e-01, -5.5339e-01,  4.8154e-02,
#           4.5662e-01,  3.2338e+00,  2.0199e-02,  4.9019e-02, -1.4132e-02,
#           7.6017e-02, -1.1527e-01,  2.0060e-01, -7.7657e-02,  2.4328e-01,
#           1.6368e-01, -3.4118e-01, -6.6070e-02,  1.0152e-01,  3.8232e-02,
#          -1.7668e-01, -8.8153e-01, -3.3895e-01, -3.5481e-02, -5.5095e-01,
#          -1.6899e-02, -4.3982e-01,  3.9004e-02,  4.0447e-01, -2.5880e-01,
#           6.4594e-01,  2.6641e-01,  2.8009e-01, -2.4625e-02,  6.3302e-01,
#          -3.1700e-01,  1.0271e-01,  3.0886e-01,  9.7792e-02, -3.8227e-01,
#           8.6552e-02,  4.7075e-02,  2.3511e-01, -3.2127e-01, -2.8538e-01,
#           1.6670e-01, -4.9707e-03, -6.2714e-01, -2.4904e-01,  2.9713e-01,
#           1.4379e-01, -1.2325e-01, -5.8178e-02, -1.0290e-03, -8.2126e-02,
#           3.6935e-01, -5.8442e-04,  3.4286e-01,  2.8426e-01, -6.8599e-02,
#           6.5747e-01, -2.9087e-02,  1.6184e-01,  7.3672e-02, -3.0343e-01,
#           9.5733e-02, -5.2860e-01, -2.2898e-01,  6.4079e-02,  1.5218e-02,
#           3.4921e-01, -4.3960e-01, -4.3983e-01,  7.7515e-01, -8.7767e-01,
#          -8.7504e-02,  3.9598e-01,  6.2362e-01, -2.6211e-01, -3.0539e-01,
#          -2.2964e-02,  3.0567e-01,  6.7660e-02,  1.5383e-01, -1.1211e-01,
#          -9.1540e-02,  8.2562e-02,  1.6897e-01, -3.2952e-02, -2.8775e-01,
#          -2.2320e-01, -9.0426e-02,  1.2407e+00, -1.8244e-01, -7.5219e-03,
#          -4.1388e-02, -1.1083e-02,  7.8186e-02,  3.8511e-01,  2.3334e-01,
#           1.4414e-01, -9.1070e-04, -2.6388e-01, -2.0481e-01,  1.0099e-01,
#           1.4076e-01,  2.8834e-01, -4.5429e-02,  3.7247e-01,  1.3645e-01,
#          -6.7457e-01,  2.2786e-01,  1.2599e-01,  2.9091e-02,  3.0428e-02,
#          -1.3028e-01,  1.9408e-01,  4.9014e-01, -3.9121e-01, -7.5952e-02,
#           7.4731e-02,  1.8902e-01, -1.6922e-01, -2.6019e-01, -3.9771e-02,
#          -2.4153e-01,  1.0875e-01,  3.0434e-01,  3.6009e-02,  1.4264e+00,
#           1.2759e-01, -7.3811e-02, -2.0418e-01,  8.0016e-03,  1.5381e-01,
#           2.0223e-01,  2.8274e-01,  9.6206e-02, -3.3634e-01,  5.0983e-01,
#           3.2625e-01, -2.6535e-01,  3.7400e-01, -3.0388e-01, -4.0033e-01,
#          -4.2910e-02, -6.7897e-02, -2.9332e-01,  1.0978e-01, -4.5365e-02,
#           2.3222e-01, -3.1134e-01, -2.8983e-01, -6.6687e-01,  5.3097e-01,
#           1.9461e-01,  3.6670e-01,  2.6185e-01, -6.5187e-01,  1.0266e-01,
#           1.1363e-01, -1.2953e-01, -6.8246e-01, -1.8751e-01,  1.4760e-01,
#           1.0765e+00, -2.2908e-01, -9.3435e-03, -2.0651e-01, -3.5225e-01,
#          -2.6720e-01, -3.4307e-03,  2.5906e-01,  2.1759e-01,  6.6158e-01,
#           1.2180e-01,  1.9957e-01, -2.0303e-01,  3.4474e-01, -2.4328e-01,
#           1.3139e-01, -8.8767e-03,  3.3617e-01,  3.0591e-02,  2.5577e-01],
#         dtype=float32)),
#  (',',
#   array([ 1.7651e-01,  2.9208e-01, -2.0768e-03, -3.7523e-01,  4.9139e-03,
#           2.3979e-01, -2.8893e-01, -1.4643e-02, -1.0993e-01,  1.5592e-01,
#           2.0627e-01,  4.7675e-01,  9.9907e-02, -1.4058e-01,  2.1114e-01,
#           1.2126e-01, -3.1831e-01, -8.9433e-02, -9.0553e-02, -3.1962e-01,
#           2.1319e-01,  2.4844e+00, -7.7521e-02, -8.4279e-02,  2.0186e-01,
#           2.6084e-01, -4.0411e-01, -1.9127e-01,  2.4715e-01,  2.2394e-01,
#          -6.3437e-02,  2.0379e-01, -1.8463e-01, -8.8413e-02,  2.4169e-02,
#          -2.8769e-01, -6.1246e-01, -1.2683e-01, -8.8273e-02,  1.8331e-01,
#          -5.3161e-01, -1.9970e-01, -2.6703e-01,  1.5312e-01, -1.5239e-02,
#          -8.2844e-02,  4.7856e-01, -2.9612e-01,  1.1168e-01, -2.5790e-02,
#          -1.1697e-02,  1.9923e-01, -1.4267e-01,  6.6250e-01, -5.1739e-02,
#          -1.6938e-01, -1.5635e-01,  9.2806e-02,  3.2548e-01,  1.1724e-01,
#           2.8788e-01, -6.0651e-02, -1.4153e-01,  1.6668e-01,  2.6861e-01,
#          -3.1001e-02, -3.9665e-01,  3.5304e-01,  2.3850e-01,  1.2388e-01,
#           4.5698e-01, -1.2559e-01, -1.2804e-01,  3.7449e-01,  2.4460e-01,
#           2.3073e-01,  2.0808e-01,  5.1258e-02, -2.1816e-01, -3.6409e-02,
#          -3.8800e-02, -4.2487e-02, -3.0779e-01, -2.5449e-02,  2.2532e-01,
#           4.5538e-02, -4.8934e-01, -1.3988e-01,  1.7394e-01, -4.6137e-01,
#          -2.6555e-01,  1.5473e-01,  6.3816e-02, -1.7022e-01, -1.5762e-01,
#           7.5765e-02,  1.2151e-01, -4.9340e-01, -1.0909e-01,  3.4487e-02,
#           2.9947e-01,  1.8690e-02, -1.6534e-01,  1.6679e-02,  1.6341e-01,
#          -2.7418e-01,  7.7797e-02,  1.4023e+00,  2.5275e-02,  9.4725e-02,
#          -4.0735e-02, -1.0642e-01,  2.3364e-02,  7.9143e-02, -1.6615e-01,
#          -2.3013e-01, -1.4071e-01,  4.0159e-01, -3.4951e-01,  1.8545e-02,
#           2.2434e-01,  7.6922e-01,  2.4722e-01,  1.4936e-01,  4.2368e-01,
#          -7.2059e-01, -3.8541e-02,  1.5522e-01,  3.3596e-01, -4.3077e-01,
#          -2.6925e-02, -3.7733e-01,  2.4271e-01, -4.6495e-01,  4.5783e-01,
#           2.3693e-01,  7.9361e-02, -3.2244e-01, -4.2434e-01, -1.1138e-01,
#           5.5426e-01,  8.5153e-02, -2.0581e-02, -4.6386e-02,  1.2467e+00,
#           1.3177e-01,  6.7092e-02, -5.7780e-01,  1.3586e-02, -7.1274e-02,
#           1.7311e-02,  8.9781e-02,  1.9857e-01, -3.2205e-02,  6.4843e-01,
#          -2.3797e-01, -1.9676e-01,  2.0203e-01,  2.1074e-01, -5.0347e-01,
#           2.6823e-02, -4.5444e-02, -2.2642e-01, -1.9977e-01, -1.2138e-01,
#           1.6941e-01,  6.1998e-02,  4.2631e-01, -8.8383e-02,  4.5756e-01,
#           7.7774e-02,  6.1342e-02,  4.5710e-01, -1.7787e-01, -1.4597e-01,
#           3.2654e-01,  2.4430e-03, -1.1886e-01,  1.0081e-01, -2.0011e-02,
#           1.0366e+00, -3.9814e-01, -6.8180e-01,  2.3685e-01, -2.0396e-01,
#          -1.7668e-01, -3.1385e-01,  1.4834e-01, -5.2187e-02,  6.1300e-02,
#          -3.2582e-01,  1.9153e-01, -1.5469e-01, -1.4679e-01,  4.6971e-02,
#           3.2325e-02, -2.2006e-01, -2.0774e-01, -2.3189e-01, -1.0814e-01],
#         dtype=float32)),
#  ('.',
#   array([ 1.2289e-01,  5.8037e-01, -6.9635e-02, -5.0288e-01,  1.0503e-01,
#           3.9945e-01, -3.8635e-01, -8.4279e-02,  1.2219e-01,  8.0312e-02,
#           3.2337e-01,  4.7579e-01, -3.8375e-02, -7.0900e-03,  4.1524e-01,
#           3.2121e-01, -2.1185e-01,  3.6144e-01, -5.5623e-02, -3.0512e-02,
#           4.2854e-01,  2.8547e+00, -1.4623e-01, -1.7557e-01,  3.1197e-01,
#          -1.3118e-01,  3.3298e-02,  1.3093e-01,  8.9889e-02, -1.2417e-01,
#           2.3396e-03, -6.8954e-02, -1.0754e-01, -1.1551e-01, -3.1052e-01,
#          -1.2097e-01, -4.6691e-01, -8.3600e-02, -3.7664e-02, -7.1779e-02,
#          -1.1899e-01, -2.0381e-01, -1.2424e-01,  4.6339e-01, -1.9828e-01,
#          -8.0365e-03,  5.3718e-01,  3.1739e-02,  3.4331e-01,  7.9704e-03,
#           4.8744e-03,  3.0592e-02, -1.7615e-01,  8.2342e-01, -1.3793e-01,
#          -1.0075e-01, -1.2686e-01,  7.4735e-02, -8.8719e-02, -4.2719e-02,
#           7.6624e-02,  8.9263e-02,  6.4445e-02, -3.1958e-02,  1.5254e-01,
#          -1.0384e-01,  7.6604e-02,  3.4099e-01,  2.4331e-01, -1.0452e-01,
#           4.0714e-01, -1.8260e-01, -4.0667e-02,  5.0878e-01,  8.0760e-02,
#           2.2759e-01, -4.2162e-02, -1.8171e-01, -9.5025e-02,  3.0334e-02,
#           8.8202e-02, -3.9843e-06, -3.9877e-03,  1.5724e-01,  3.3167e-01,
#           8.4710e-02, -2.5919e-01, -4.1384e-01,  2.9920e-01, -5.4255e-01,
#           3.2129e-02,  1.0030e-01,  4.4202e-01,  4.4682e-02, -9.0681e-02,
#          -1.0481e-01, -1.1860e-01, -3.1972e-01, -2.0790e-01, -4.0203e-02,
#          -2.2988e-02,  2.2824e-01,  5.5238e-03,  1.2568e-01, -1.4640e-01,
#          -1.4904e-01, -1.1561e-01,  1.0517e+00, -1.9498e-01,  8.3958e-02,
#           4.4812e-02, -1.2965e-01, -9.3468e-02,  2.1237e-01, -8.8332e-02,
#          -1.8680e-01,  2.6521e-01,  1.3097e-01, -4.8102e-02, -2.2467e-01,
#           2.8412e-01,  3.4907e-01,  3.4833e-01,  1.7877e-02,  3.0504e-01,
#          -8.3453e-01,  4.8856e-02, -1.9330e-01,  2.0764e-01, -4.9701e-01,
#          -1.8747e-01, -7.6801e-02,  1.5558e-01, -4.6844e-01,  4.0944e-01,
#           2.1386e-01,  8.2392e-02, -2.6491e-01, -2.1224e-01, -1.3293e-01,
#           1.4738e-01, -1.4192e-01,  1.8994e-01, -1.5587e-01,  1.0738e+00,
#           4.0789e-01, -2.7452e-01, -1.8431e-01,  6.8679e-04, -8.7115e-02,
#           1.9672e-01,  4.0918e-01, -3.5462e-01, -6.3260e-02,  4.4920e-01,
#          -6.0568e-02, -4.1636e-02,  2.0531e-01,  1.7025e-02, -5.8448e-01,
#           7.5441e-02,  8.2116e-02, -4.6008e-01,  1.2393e-02, -2.5310e-02,
#           1.4177e-01, -9.2192e-02,  3.4505e-01, -5.2136e-01,  5.7304e-01,
#           1.1973e-02,  3.3196e-02,  2.9672e-01, -2.7899e-01,  1.9979e-01,
#           2.5666e-01,  8.2079e-02, -7.8436e-02,  9.3719e-02,  2.4202e-01,
#           1.3495e+00, -3.0434e-01, -3.0936e-01,  4.2047e-01, -7.9068e-02,
#          -1.4819e-01, -8.9404e-02,  6.6800e-02,  2.2405e-01,  2.7226e-01,
#          -3.5236e-02,  1.7688e-01, -5.3600e-02,  7.0031e-03, -3.3006e-02,
#          -8.0021e-02, -2.4451e-01, -3.9174e-02, -1.6236e-01, -9.6652e-02],
#         dtype=float32)),
#  ('of',
#   array([ 5.2924e-02,  2.5427e-01,  3.1353e-01, -3.5613e-01,  2.9629e-02,
#           5.1034e-01, -1.0716e-01,  1.5195e-01,  5.7698e-02,  6.1490e-02,
#           6.1160e-02,  3.9911e-01, -2.9018e-04,  3.1978e-01,  4.3257e-01,
#          -1.4708e-01,  5.4842e-02,  2.7079e-01, -1.4051e-01, -3.0101e-01,
#           1.6313e-01,  3.0013e+00,  2.2231e-01, -1.4279e-01,  8.3705e-02,
#           8.9866e-02, -5.2706e-01, -8.9661e-02,  2.7311e-01,  3.1413e-01,
#          -4.0810e-02,  6.0557e-02, -4.2656e-02,  2.4178e-01, -2.9187e-01,
#           2.2575e-01, -6.2980e-01, -1.4641e-01, -2.2429e-01, -5.6621e-02,
#          -1.7776e-01, -6.4269e-01,  5.1626e-01,  2.2305e-01,  1.2124e-01,
#           4.8074e-01,  4.1743e-01,  5.4805e-01,  4.0955e-01,  4.2407e-01,
#           4.9906e-02, -3.2574e-01,  4.6298e-01,  1.9245e-01,  2.8143e-01,
#           2.9660e-01,  6.3593e-02, -1.1906e-01, -1.5016e-01, -4.9840e-02,
#           4.0675e-01,  1.0675e-02, -6.9127e-01,  4.8729e-02,  2.6391e-01,
#           3.0961e-01, -1.1921e-01,  2.5548e-01, -2.8219e-01, -3.7413e-02,
#           3.6461e-01,  2.7129e-02,  2.0786e-01,  5.3325e-01,  5.0148e-01,
#           7.2381e-01,  6.5292e-02, -7.8716e-02, -1.0537e-01, -8.0810e-02,
#          -2.0960e-01,  4.0902e-02, -8.8101e-01,  2.4715e-01,  1.6146e-01,
#           1.0361e-01,  1.9705e-01, -2.7365e-01,  8.9902e-01, -2.9981e-01,
#           3.6165e-02,  4.1238e-02,  6.0105e-01, -1.8911e-01, -4.3887e-01,
#          -1.4097e-01,  4.4073e-01, -1.9999e-01,  2.8834e-01, -2.5458e-01,
#          -1.0985e-01, -2.7379e-03,  9.1735e-02,  1.7021e-01, -1.6305e-01,
#          -5.7439e-01,  3.7063e-01,  1.7262e+00, -2.4656e-01,  5.1681e-01,
#          -1.5355e-01, -1.5553e-01,  1.9783e-02,  1.8030e-01,  3.8178e-01,
#           9.4443e-02, -5.5158e-01, -2.0242e-01, -4.3860e-01, -4.2108e-01,
#           2.7525e-01,  5.8977e-01,  2.6655e-02,  1.6401e-01,  1.3893e-01,
#          -6.8692e-01,  5.1071e-01,  2.9278e-01,  2.2041e-02, -1.8156e-01,
#          -6.4905e-01,  1.6923e-01, -1.0590e-02,  2.1785e-01, -2.7242e-01,
#           2.7967e-01,  1.3950e-01, -7.0559e-01, -2.6034e-01, -4.4017e-01,
#           1.5303e-01,  1.9693e-01, -9.6838e-02,  1.4827e-01,  1.1294e+00,
#          -3.1267e-01,  9.9916e-03, -4.8623e-01,  8.0584e-02,  3.5608e-01,
#          -1.9925e-01,  1.9306e-01, -2.0040e-01, -4.4194e-01,  7.5766e-01,
#           2.4487e-01, -1.8903e-01,  2.6653e-01, -2.1339e-01, -5.4083e-01,
#           4.0532e-01, -2.7960e-02, -1.3398e-01, -1.1086e-01,  5.9506e-02,
#           2.4052e-01, -5.9739e-01, -2.4069e-03, -1.8593e-01,  1.0420e+00,
#          -1.2969e-01,  2.0813e-01,  3.3305e-01, -1.2780e-01,  8.5662e-02,
#          -7.6422e-02,  3.1407e-01, -2.3784e-01, -5.4838e-02,  1.1369e-02,
#           8.4500e-01, -3.4165e-01,  9.3983e-02,  8.2445e-02, -2.7777e-01,
#          -4.4226e-01, -6.3078e-02,  3.7274e-01,  5.4468e-02,  2.4197e-01,
#          -4.0886e-02,  3.8940e-01, -1.0509e-01,  2.3372e-01,  9.6027e-02,
#          -3.0324e-01,  2.4488e-01, -8.6254e-02, -4.1917e-01,  4.6496e-01],
#         dtype=float32)),
#  ('to',
#   array([ 5.7346e-01,  5.4170e-01, -2.3477e-01, -3.6240e-01,  4.0370e-01,
#           1.1386e-01, -4.4933e-01, -3.0991e-01, -5.3411e-03,  5.8426e-01,
#          -2.5956e-02,  4.9393e-01, -3.7209e-02, -2.8428e-01,  9.7696e-02,
#          -4.8907e-01,  2.6027e-02,  3.7649e-01,  5.7788e-02, -4.6807e-01,
#           8.1288e-02,  3.2825e+00, -6.3690e-01,  3.7956e-01,  3.8167e-03,
#           9.3607e-02, -1.2855e-01,  1.7380e-01,  1.0522e-01,  2.8648e-01,
#           2.1089e-01, -4.7076e-01,  2.7733e-02, -1.9803e-01,  7.6328e-02,
#          -8.4629e-01, -7.9708e-01, -3.8743e-01, -3.0422e-02, -2.6849e-01,
#           4.8585e-01,  1.2895e-01,  3.8354e-01,  3.8722e-01, -3.8524e-01,
#           1.9075e-01,  4.8998e-01,  1.3278e-01,  1.0792e-02,  2.6770e-01,
#           1.7812e-01, -1.1433e-01, -3.3494e-01,  8.7306e-01,  7.5875e-01,
#          -3.0378e-01, -1.5626e-01,  1.2085e-03,  2.3322e-01,  2.7953e-01,
#          -1.8494e-01, -1.4146e-01, -1.8969e-01, -3.8386e-02,  3.5874e-01,
#           6.5513e-02,  6.0565e-02,  6.6339e-01, -8.3252e-02,  6.5163e-02,
#           5.1761e-01,  1.6171e-01,  4.6011e-01,  1.6388e-01, -1.2399e-01,
#           3.1122e-01, -1.5412e-01, -1.0917e-01, -4.2551e-01,  1.1418e-01,
#           2.5137e-01, -5.6158e-02, -2.5927e-01,  2.8163e-01, -1.8094e-02,
#           1.6065e-01, -4.8506e-01, -9.8903e-01,  2.5022e-01, -1.6736e-01,
#           4.1474e-01,  1.7701e-01,  4.2407e-01,  1.1088e-01, -1.8360e-01,
#          -1.2410e-01, -3.4780e-01,  9.9078e-02, -2.2381e-01, -1.1245e-01,
#          -2.1156e-01,  3.0706e-03, -2.3607e-01,  2.7261e-02,  3.6430e-01,
#           3.9922e-02, -1.8369e-01,  1.2266e+00, -7.7640e-01, -6.6225e-01,
#           1.5724e-02, -1.4969e-01,  8.4649e-02,  2.6814e-01, -1.6765e-01,
#          -3.1942e-01,  2.8494e-01, -7.0000e-02,  1.2010e-02, -1.2219e-01,
#           5.6310e-01, -3.2000e-01,  5.0109e-01, -1.0209e-01,  4.6575e-01,
#          -7.1542e-01,  1.7293e-01,  5.8259e-01,  7.8384e-02, -3.3844e-02,
#          -2.5129e-01,  3.6503e-01,  3.1578e-02, -6.5778e-01,  5.4750e-02,
#           8.7189e-01,  1.2455e-01, -4.5877e-01, -2.6965e-01, -4.6779e-01,
#          -2.8578e-03,  1.7810e-01,  6.3969e-01,  1.3995e-01,  9.7596e-01,
#           1.1836e-01, -6.3904e-01, -1.5416e-01,  6.5262e-02,  2.4329e-01,
#           6.6476e-01,  2.5069e-01, -1.0252e-01, -3.2839e-01, -8.5559e-02,
#          -1.2774e-02, -1.9431e-01,  5.6139e-01, -3.5733e-01, -2.0344e-01,
#          -1.2413e-01, -3.4431e-01, -2.3296e-01, -2.1187e-01,  8.5387e-02,
#           7.0063e-02, -1.9803e-01, -2.6023e-02, -3.9037e-01,  8.0002e-01,
#           4.0577e-01, -7.9863e-02,  3.5263e-01, -3.4043e-01,  3.9676e-01,
#           2.2862e-01, -3.5028e-01, -4.7344e-01,  5.9742e-01, -1.1657e-01,
#           1.0552e+00, -4.1570e-01, -8.0552e-02, -5.6571e-02, -1.6622e-01,
#           1.9274e-01, -9.5175e-02, -2.0781e-01,  1.5620e-01,  5.0231e-02,
#          -2.7915e-01,  4.3742e-01, -3.1237e-01,  1.3194e-01, -3.3278e-01,
#           1.8877e-01, -2.3422e-01,  5.4418e-01, -2.3069e-01,  3.4947e-01],
#         dtype=float32)),
#  ('and',
#   array([ 2.0327e-01,  4.7348e-01,  5.0877e-02,  2.1030e-03,  6.0547e-02,
#           3.3066e-01,  4.8486e-02,  2.1504e-02, -5.3631e-01,  2.1312e-01,
#           1.9983e-01,  5.1408e-01,  7.0422e-04,  9.4641e-02,  6.8724e-02,
#           2.7424e-01, -2.0493e-01,  2.3268e-01,  3.2490e-01, -1.9444e-01,
#           6.4693e-01,  2.8342e+00,  1.4004e-01, -2.6868e-01,  2.7325e-01,
#           1.5312e-02, -2.7975e-01, -2.6423e-01,  1.4183e-01, -2.6064e-02,
#           1.1349e-01,  2.5039e-01, -2.4972e-01, -1.6882e-01, -3.1039e-01,
#          -4.4458e-01, -3.4789e-01, -2.0181e-01, -1.3405e-02,  2.3635e-01,
#           1.7741e-01, -1.0535e-01, -2.0716e-01,  3.7856e-01,  1.0507e-01,
#          -3.0970e-01,  4.6782e-01, -5.0021e-01,  2.6643e-01,  5.1564e-01,
#           5.4247e-02,  5.0546e-01, -2.4959e-01,  5.4021e-01,  1.7268e-01,
#          -3.8650e-02,  2.3730e-02,  2.4111e-01,  1.7210e-01,  7.8734e-02,
#           3.1275e-01,  1.8700e-01, -4.5933e-01,  5.5853e-01,  2.2511e-01,
#           1.6761e-01, -4.5662e-02,  5.5918e-01, -2.4065e-01, -2.4904e-01,
#           3.8718e-01, -2.1586e-01, -1.0332e-01,  2.4157e-01, -1.8440e-01,
#           3.1295e-01, -1.6315e-01, -2.1771e-01,  1.8137e-01, -4.5089e-02,
#           6.8367e-02, -1.7317e-01, -7.9639e-01,  2.4492e-01,  1.2389e-01,
#           1.1703e-01, -8.8345e-02, -3.7042e-01,  4.3759e-01, -4.7564e-01,
#          -9.5386e-02, -1.5975e-01,  1.8380e-01,  2.5664e-01, -4.1276e-01,
#           4.7558e-02,  1.6437e-01, -2.6353e-01, -2.7328e-01, -8.9788e-02,
#           3.1598e-01, -1.1246e-01, -1.8703e-01,  2.0422e-01,  6.8352e-02,
#           1.1667e-02,  1.3657e-01,  1.1524e+00,  2.4065e-02, -1.1591e-01,
#          -1.8142e-01, -3.6441e-01, -1.0051e-02,  1.9956e-01,  2.6850e-01,
#          -9.5357e-02, -1.1906e-01,  3.2378e-01, -1.9527e-01, -3.6800e-01,
#          -3.8172e-03,  3.9600e-01,  2.4194e-01,  3.1296e-01,  2.4128e-01,
#          -7.6120e-01,  7.1389e-02,  4.2396e-01,  2.6369e-01, -9.1366e-02,
#          -1.3438e-01, -1.7673e-01,  1.3168e-02, -6.2400e-01,  1.7744e-01,
#           3.8957e-01, -3.7665e-02, -1.2586e-01, -1.4862e-01, -2.9635e-01,
#           4.0572e-01, -7.1653e-02, -1.1642e-01, -1.6958e-01,  1.0982e+00,
#           3.9618e-01, -1.6874e-01, -6.0360e-01,  4.1394e-01,  2.8977e-01,
#           1.1419e-01, -4.7337e-02, -3.3519e-03, -4.2435e-01,  6.1701e-01,
#          -1.0480e-02, -2.8841e-01,  4.2077e-01, -7.5991e-02, -3.8083e-01,
#           5.7339e-01,  1.8044e-01, -1.1781e-01,  3.5162e-01,  1.6220e-01,
#           5.5483e-01,  1.4000e-01,  2.3210e-01, -2.0205e-01,  6.0227e-01,
#          -1.5379e-01,  2.1907e-01,  2.8405e-01,  1.1906e-02,  1.0622e-01,
#           5.0670e-01, -4.3201e-01, -4.0887e-01, -1.7819e-01,  2.2042e-01,
#           1.0775e+00, -3.9381e-01, -3.5828e-01,  3.6302e-01,  1.4872e-01,
#           3.5555e-02, -3.0339e-02, -1.1273e-01,  2.3382e-02,  1.5904e-01,
#          -1.4389e-01, -1.1754e-01, -6.3655e-01, -1.2197e-01,  4.3809e-02,
#           1.4716e-01,  7.3750e-02, -2.1358e-01, -6.2249e-01,  1.4386e-01],
#         dtype=float32)),
#  ('in',
#   array([-1.0272e-01,  3.0410e-01, -1.3577e-01, -2.7979e-01, -4.0926e-01,
#          -2.6553e-01,  1.0492e-01, -4.4101e-02,  6.2731e-02, -4.1600e-02,
#           3.5588e-01,  4.0757e-01, -1.4295e-01, -3.6534e-02,  4.2512e-01,
#           1.4823e-02,  3.0443e-04,  2.9150e-01, -2.0416e-01, -1.0039e-01,
#           3.0767e-01,  3.1815e+00,  4.5614e-02,  9.4457e-02,  2.5545e-01,
#           2.7528e-01, -2.9939e-01,  4.5123e-02,  4.4681e-01,  1.5012e-02,
#          -1.0785e-01, -3.8988e-01, -2.0562e-01,  2.6306e-01, -1.8163e-02,
#          -1.4244e-01, -5.6610e-01, -1.2168e-01,  2.8749e-01, -3.0581e-01,
#          -4.4820e-01, -1.5317e-01, -1.9445e-01,  3.5335e-01, -1.5209e-02,
#           2.3061e-01,  1.3566e-01, -2.6385e-01,  6.6084e-02,  1.6075e-01,
#           1.2168e-01,  7.2758e-01,  3.2453e-01,  8.2149e-01, -1.3693e-01,
#          -2.0060e-01, -9.7958e-02, -1.5446e-01, -3.8003e-01,  1.5699e-01,
#           4.1498e-02, -2.2766e-01, -4.0033e-01,  2.5514e-01,  1.3092e-01,
#           2.4261e-01, -4.8639e-01, -2.7622e-01, -2.1293e-01, -1.1668e-01,
#           1.4564e-02,  2.1658e-01,  1.9006e-01,  4.0863e-01,  4.8486e-01,
#           4.0370e-01,  2.0366e-01, -9.6563e-02,  1.9522e-01, -1.6715e-01,
#          -3.1923e-01, -3.5499e-01, -3.4792e-01,  5.9981e-01, -4.6506e-02,
#          -2.7371e-01,  1.3404e-02, -3.6558e-01,  6.9315e-01, -2.4070e-01,
#          -1.3700e-02,  2.2596e-01,  2.1897e-01,  1.0207e-02, -2.3484e-01,
#          -3.6304e-01,  1.0290e-01, -4.2780e-01,  2.8864e-01, -4.3645e-01,
#          -8.3785e-02,  1.1830e-01,  2.0385e-01,  4.0474e-01, -7.9155e-02,
#          -1.2931e-01,  7.7845e-02,  1.2303e+00, -5.5546e-01,  1.5620e-01,
#           6.3933e-03, -4.6652e-01,  1.3173e-02,  5.2646e-01, -2.3626e-01,
#           1.3833e-02,  1.0002e-01,  9.0947e-02, -2.5318e-01, -6.4795e-01,
#           6.3422e-02,  7.4095e-01,  2.9020e-01,  2.2642e-01,  3.3915e-01,
#          -8.0488e-01,  2.1889e-01,  1.9193e-01,  5.5390e-02, -3.9976e-01,
#           9.4308e-03,  2.6978e-01,  6.3166e-01, -4.1242e-01,  2.0485e-01,
#           3.3116e-01,  1.1562e-01, -4.5671e-01, -4.8083e-01,  4.6172e-01,
#           2.7319e-01,  2.4300e-01,  1.2328e-01,  2.3070e-01,  1.2257e+00,
#           3.7079e-02,  2.3077e-01, -3.1092e-01, -9.9628e-02,  4.1876e-01,
#          -9.3834e-02, -2.4741e-01, -4.9863e-01, -7.4542e-01,  1.6518e-01,
#           6.9734e-02,  6.6691e-02, -9.2037e-02,  2.1124e-01, -2.8236e-01,
#           2.0825e-01, -1.7163e-01, -3.2025e-01, -2.7537e-01, -3.0774e-01,
#           1.8184e-01, -2.6260e-02, -6.2733e-02, -4.3666e-01,  5.7954e-01,
#          -3.2348e-01, -1.3457e-01,  3.8565e-01, -3.0198e-01,  2.6197e-01,
#          -1.0034e-01, -1.4600e-01, -3.4170e-01,  1.6671e-01, -2.3599e-01,
#           1.2467e+00, -5.9839e-03, -5.6967e-01,  5.2640e-01, -2.1024e-01,
#          -2.9861e-01, -2.9300e-01,  1.5889e-01,  1.7254e-01, -2.3984e-03,
#           7.1749e-02,  5.3166e-02, -2.3429e-01, -8.4927e-02,  1.5539e-01,
#           4.1820e-01, -1.5216e-01,  3.6951e-01,  1.9039e-01, -1.2266e-01],
#         dtype=float32)),
#  ('a',
#   array([ 2.4169e-01, -3.4534e-01, -2.2307e-01, -1.2907e+00,  2.5285e-01,
#          -5.5128e-01, -8.0336e-02, -8.1767e-03,  3.1136e-01, -4.5101e-01,
#           2.4661e-01,  3.6441e-01,  9.4336e-01, -3.5420e-02,  7.8048e-01,
#          -3.9765e-01,  3.1125e-01, -1.7743e-01, -4.1989e-01, -3.7815e-01,
#           6.7230e-01,  3.1716e+00,  3.2496e-02, -3.1640e-02,  5.8068e-01,
#          -4.4458e-01, -5.5612e-02,  1.8052e-01,  2.8572e-01,  9.5870e-02,
#           2.1437e-01,  4.9731e-02,  1.8720e-01,  1.1914e-01,  2.7408e-02,
#          -8.0608e-01, -3.0835e-01, -8.9737e-01, -1.9772e-01,  2.6741e-02,
#          -3.8765e-01,  1.1659e-01, -2.0110e-01,  2.0101e-01, -7.9133e-02,
#          -5.0954e-02,  6.0189e-03,  3.3470e-01, -2.1118e-01,  7.4042e-02,
#          -2.8141e-01, -5.9615e-02, -3.5296e-01,  6.4748e-01,  5.3908e-02,
#          -3.1376e-01, -3.6622e-01, -2.7755e-01,  2.2676e-02,  4.8811e-02,
#           1.4312e-01, -1.8580e-01, -5.6964e-01, -5.4119e-01,  1.8616e-01,
#           1.8854e-01,  2.7521e-01, -1.7835e-01, -3.7438e-01,  1.2109e-01,
#           1.8610e-03, -9.2127e-03,  1.0186e-01,  9.8081e-02, -3.7245e-01,
#           6.6415e-01,  5.7366e-02, -4.3845e-01, -4.0525e-01, -5.5959e-01,
#          -1.1343e-01, -5.4987e-01, -2.6321e-01, -2.8471e-01,  1.4411e-01,
#           1.0360e-01, -3.2198e-01, -2.1530e-01,  9.8668e-01, -4.1937e-01,
#           3.1190e-01,  3.3380e-01,  1.6018e-01,  3.3137e-01, -2.5494e-02,
#          -3.7880e-02, -1.2048e-01, -1.2175e-01,  9.4766e-02,  2.6158e-01,
#           2.9931e-02, -2.9625e-01,  4.3401e-01, -3.6536e-02, -4.2852e-01,
#          -3.9638e-01, -2.4973e-01,  1.1018e+00, -2.2812e-01,  2.4324e-01,
#           8.3857e-02, -4.8881e-01, -2.1316e-01,  4.0249e-02, -4.0516e-01,
#          -1.2411e-01, -1.9728e-01, -7.3696e-01, -4.4582e-01, -4.4992e-01,
#          -7.3707e-02, -1.6454e-01,  1.6011e-01, -4.1952e-01,  4.1417e-01,
#          -5.7277e-01,  5.1367e-01,  8.1118e-02,  2.9288e-02,  3.5309e-01,
#          -1.0803e-01,  1.3702e-01,  3.8828e-01, -2.8813e-01,  6.8203e-01,
#           1.7412e-01, -8.8540e-02, -2.9785e-01, -2.8455e-01,  1.3570e-01,
#           1.5232e-01,  2.2037e-01,  6.8812e-01, -1.3100e-01,  1.8197e+00,
#          -4.5153e-01,  3.9553e-01, -6.0817e-01,  3.3698e-01,  1.1090e-01,
#          -2.8476e-01,  3.0461e-01, -2.1606e-01, -5.8111e-02,  4.4172e-01,
#          -2.4231e-01, -1.2758e-01, -4.8793e-02, -1.5495e-01, -8.5491e-01,
#           9.2912e-02, -6.0809e-02,  2.9073e-02, -3.8735e-01, -7.0853e-02,
#          -6.5975e-01, -3.8157e-01,  5.0170e-01, -7.3560e-01,  4.1521e-01,
#           2.1328e-01, -3.3779e-01,  6.6902e-01,  4.2486e-01, -1.2148e-01,
#          -1.0626e-02,  1.2745e-01, -1.3561e-01,  2.3423e-01,  3.5110e-01,
#           1.2841e+00,  1.2982e-01,  2.1357e-01,  3.2857e-01,  1.6567e-01,
#          -2.1458e-01, -4.4275e-01,  3.2850e-01,  1.8001e-01,  6.4865e-02,
#          -3.5880e-01, -1.4226e-02,  3.1125e-01, -2.2049e-01,  3.2829e-02,
#           3.8525e-01, -1.0512e-01,  2.7801e-01, -1.0171e-01, -7.1521e-02],
#         dtype=float32)),
#  ('"',
#   array([ 1.0318e-03,  3.1201e-01, -5.9768e-01, -1.2583e-01, -2.7524e-01,
#           2.9145e-01, -3.0431e-01,  3.7122e-02,  9.4468e-01,  8.8085e-02,
#          -9.6273e-02,  4.0542e-01, -6.5240e-01,  3.7716e-01,  5.3001e-01,
#          -3.0819e-01, -2.7478e-01,  8.1041e-01,  5.3635e-01,  8.7590e-02,
#           3.5288e-01,  2.8857e+00, -1.2505e-01, -3.5968e-02,  1.3550e-01,
#          -2.9932e-01,  5.6154e-01, -5.9429e-01, -3.4991e-01,  6.8559e-01,
#          -1.1537e-01,  8.8894e-02, -2.9829e-01, -2.0768e-01,  6.9110e-01,
#           6.8548e-02, -5.0814e-01, -9.7722e-01,  3.5782e-02, -5.4053e-01,
#          -1.6178e-01,  4.7542e-01, -7.1652e-01,  3.1939e-01, -4.9291e-02,
#           3.2565e-01,  5.5510e-01, -4.2967e-01,  1.0137e+00,  3.0304e-01,
#           4.4503e-01,  4.6987e-01,  7.4292e-02, -3.5762e-01, -1.3736e-01,
#          -1.6066e-01, -2.8606e-01,  1.2358e-04, -4.3422e-02, -3.6702e-01,
#           4.0895e-01, -4.0467e-01, -5.1635e-01,  2.8044e-01, -2.7625e-01,
#          -2.0352e-01,  8.4837e-02,  7.8145e-02,  3.2895e-01,  2.0482e-01,
#           1.7551e-01, -2.3090e-01, -6.6328e-02,  4.6467e-01, -3.8932e-01,
#          -2.3018e-01, -9.8122e-02, -1.2376e-01, -2.8503e-02,  4.0342e-02,
#           7.1158e-01, -2.7804e-01,  1.0137e-01,  5.1113e-01, -4.2648e-01,
#          -1.2535e-01, -3.9139e-01,  2.9972e-01,  1.8680e-01, -5.8113e-01,
#           3.8192e-01,  1.6540e-01,  3.3566e-01, -4.7696e-01, -2.4135e-01,
#          -3.3114e-01,  3.4815e-01, -8.7061e-02, -1.6406e-01, -1.0230e-01,
#           5.3301e-01,  4.5604e-01,  3.3281e-01, -3.3851e-01,  3.0248e-01,
#          -1.5048e-01, -3.3033e-01,  6.6680e-01, -2.8609e-01,  1.0374e+00,
#          -7.0909e-01, -8.4268e-02,  4.7584e-01, -1.6125e-01,  1.9906e-01,
#           5.1991e-01,  2.6676e-02, -2.5567e-01, -3.2363e-01,  1.3236e-01,
#           5.4006e-01,  9.3419e-02,  1.2268e-01, -6.2967e-01,  7.4921e-04,
#          -5.3441e-01,  2.5609e-01,  3.9963e-01,  8.0527e-01, -4.1176e-01,
#           1.8955e-01,  2.4526e-02, -2.0222e-01,  3.3781e-01,  7.8720e-03,
#          -6.4424e-01, -5.3090e-01,  2.7875e-02,  8.8964e-02,  2.9687e-01,
#          -3.8186e-02,  7.7967e-01, -6.9213e-02, -5.8387e-01,  1.1816e+00,
#           6.0791e-01, -4.0210e-01, -3.2223e-01, -7.1283e-02, -2.2764e-02,
#          -4.6393e-01,  9.9797e-01, -1.5308e-01,  4.7120e-01,  7.3921e-01,
#          -1.2487e-01, -3.8275e-01, -3.9598e-01,  1.2852e-01, -4.9510e-01,
#           1.9752e-01, -2.5436e-01,  1.6616e-01, -1.8135e-01,  1.6374e-01,
#          -1.6194e-01, -3.2013e-01, -3.3111e-01,  5.3662e-01,  5.3301e-01,
#          -3.2166e-01, -6.4362e-01,  1.0576e+00, -1.8019e-01, -4.0932e-01,
#          -1.6084e-01, -1.0094e+00,  2.2972e-01,  5.4310e-01,  5.8910e-02,
#           1.7502e+00, -1.9753e-01, -5.4010e-02,  1.6083e-02, -5.5523e-01,
#          -2.0231e-01, -3.2613e-01, -3.8783e-01,  6.1428e-01, -1.1216e-01,
#           4.2319e-01, -4.4729e-01, -3.5638e-01, -3.2698e-01, -1.2662e-01,
#          -2.8858e-01,  8.0920e-02,  1.4493e-01,  5.2563e-02,  7.5007e-01],
#         dtype=float32)),
#  ("'s",
#   array([-5.9614e-03,  4.5148e-01,  4.5495e-03,  2.0727e-02,  5.3877e-01,
#           4.9453e-01, -3.5369e-01, -5.6286e-02,  5.7851e-02, -2.0450e-01,
#          -3.0640e-01,  3.7904e-01,  2.6388e-01,  3.6036e-01,  6.8715e-01,
#           1.1629e-01, -5.7005e-01,  8.4364e-02, -6.7184e-01,  2.1706e-01,
#           6.0084e-01,  3.1461e+00,  2.1839e-01,  1.8830e-01, -1.1606e-02,
#           7.0280e-01, -5.4734e-02, -5.7602e-01, -5.0561e-01,  1.3275e-01,
#          -3.7349e-01, -2.2315e-01,  1.8934e-01, -3.8835e-01, -4.4616e-01,
#           2.5078e-01, -2.4067e-01, -2.7303e-01, -6.3587e-01,  7.1991e-02,
#          -3.0948e-01, -6.5413e-01, -7.5834e-02,  4.0565e-01, -2.8402e-01,
#           4.4169e-01, -2.2619e-01,  1.0845e-01, -1.5489e-02, -3.0989e-01,
#          -2.1780e-02, -1.1869e-01,  1.7083e-01, -9.9277e-02,  3.0043e-01,
#           1.8093e-01, -2.5603e-01,  8.4124e-02,  5.2387e-02,  6.1726e-01,
#           2.1400e-01, -2.2772e-01, -8.7764e-01, -1.4982e-01, -2.3043e-01,
#          -3.5754e-04, -3.2101e-01,  2.7185e-02,  2.1575e-01,  3.6466e-01,
#           6.2460e-01, -1.2043e-01,  5.1410e-02,  9.1292e-01,  1.8761e-01,
#           9.3069e-01, -3.5316e-01, -1.7359e-01, -2.9801e-01, -4.7032e-01,
#          -3.0814e-01, -3.0579e-02,  1.0451e-03, -4.2480e-01,  2.5234e-02,
#           1.0384e-01, -4.8836e-01, -5.2485e-02,  4.0014e-01, -7.4950e-01,
#          -1.3414e-01,  4.4740e-01, -2.9949e-01,  9.7470e-02, -5.5787e-01,
#           2.0784e-01,  7.8450e-02, -1.8413e-02,  5.1101e-01, -8.1727e-02,
#          -1.2922e-01,  2.6656e-01,  1.9702e-02,  3.2468e-01, -6.5269e-03,
#          -6.1234e-01,  1.6835e-01,  1.4625e+00, -6.9953e-01, -4.9550e-01,
#          -1.4897e-01, -3.1528e-01, -8.4419e-01,  1.5958e-02, -3.2832e-01,
#           1.7431e-01, -1.7892e-01,  1.9392e-01, -1.8366e-01,  2.5364e-02,
#           2.6547e-01,  4.4295e-01,  3.8296e-01, -8.7653e-02,  7.2418e-01,
#          -4.8724e-01,  1.4929e-02, -2.4590e-01, -2.6036e-02,  1.3949e-01,
#           1.2917e-01, -2.9052e-01,  2.4795e-01, -7.4504e-01, -1.2584e-01,
#           6.6134e-01,  1.4745e-01,  2.0824e-02, -1.7371e-01, -1.0235e-01,
#          -3.8495e-01,  8.5243e-01,  3.4448e-01,  4.6187e-01,  1.2913e+00,
#           8.5984e-02, -1.3995e-01, -7.7678e-01,  3.3022e-01,  4.4620e-01,
#           4.7170e-01,  1.1727e-01,  6.1142e-01,  3.9587e-01,  3.4127e-01,
#          -8.4882e-02, -1.8584e-01,  7.6045e-02, -3.3183e-01,  5.2621e-02,
#           6.6403e-01, -1.9629e-01, -6.6911e-02,  2.0812e-01,  2.9366e-01,
#           3.3020e-01, -2.1909e-01, -2.7987e-01,  1.1026e-01,  4.7563e-01,
#           4.9742e-01,  7.1567e-02,  1.9419e-01, -1.3688e-01, -6.9569e-02,
#           4.9701e-01, -8.4327e-01, -4.4757e-01,  5.0253e-01,  6.0596e-01,
#           8.6543e-01,  4.7559e-01, -9.3512e-03,  8.1187e-04, -5.9952e-01,
#          -1.2317e-01, -3.0361e-01,  1.7132e-01,  8.2369e-01,  2.6790e-01,
#           3.3455e-01,  3.5521e-01, -5.6247e-01,  3.7289e-01,  5.1554e-01,
#          -3.6403e-03,  7.6358e-02,  3.9947e-01,  2.9621e-01,  5.3627e-02],
#         dtype=float32))]

# %%
len(embeddings_index)
# Out:
# 400000

# %%
len(next(iter(embeddings_index.values())))
# Out:
# 200

# %%
#  For modeling, It is to load word embeddings into an embedding matrix.
# Because I shall use this matrix in the modeling process to represent words.
embedding_dim = 200

vocab_size = len(tokenizer.word_index) + 1 # The tokenizer object uses padding for index 0, so +1 is added.

embedding_matrix = np.zeros((vocab_size, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i < vocab_size:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# %% [markdown]
# ## Modeling

# %%
model = Sequential([
        Embedding(input_dim=vocab_size,
              output_dim=embedding_dim,
              input_length=max_len,
              weights=[embedding_matrix],
              trainable=False, name='embedding_layer'),
        LSTM(128),
        BatchNormalization(),
        Dropout(0.2),
        Dense(6, activation='softmax')
])


model.compile(loss='sparse_categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

model.summary()

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    verbose=1,
    restore_best_weights=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_layer (Embedding)          │ ?                           │       3,013,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,013,000 (11.49 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 3,013,000 (11.49 MB)

# %%
history = model.fit(X_train, y_train,
                    epochs=100,
                    validation_data=(X_val, y_val),
                    batch_size=32,
                    verbose=1,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.5049 - loss: 1.3999 - val_accuracy: 0.7855 - val_loss: 0.6530
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8211 - loss: 0.5075 - val_accuracy: 0.8925 - val_loss: 0.3113
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8928 - loss: 0.2923 - val_accuracy: 0.8815 - val_loss: 0.3380
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9212 - loss: 0.2152 - val_accuracy: 0.9045 - val_loss: 0.2623
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9378 - loss: 0.1621 - val_accuracy: 0.9115 - val_loss: 0.2750
# Epoch 6/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9505 - loss: 0.1325 - val_accuracy: 0.9180 - val_loss: 0.2288
# Epoch 7/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9586 - loss: 0.1123 - val_accuracy: 0.9175 - val_loss: 0.2206
# Epoch 8/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9605 - loss: 0.1030 - val_accuracy: 0.9190 - val_loss: 0.2391
# Epoch 9/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9649 - loss: 0.0870 - val_accuracy: 0.9140 - val_loss: 0.2681
# Epoch 10/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9682 - loss: 0.0854 - val_accuracy: 0.9195 - val_loss: 0.2302
# Epoch 11/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9717 - loss: 0.0722 - val_accuracy: 0.9230 - val_loss: 0.2501
# Epoch 12/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9773 - loss: 0.0671 - val_accuracy: 0.9125 - val_loss: 0.2732
# Epoch 13/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9770 - loss: 0.0626 - val_accuracy: 0.9220 - val_loss: 0.2272
# Epoch 14/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9803 - loss: 0.0561 - val_accuracy: 0.9220 - val_loss: 0.2338
# Epoch 15/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.9839 - loss: 0.0499 - val_accuracy: 0.9175 - val_loss: 0.2450
# Epoch 16/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9823 - loss: 0.0476 - val_accuracy: 0.9260 - val_loss: 0.2871
# Epoch 17/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.9822 - loss: 0.0466 - val_accuracy: 0.9230 - val_loss: 0.2896
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print(f"Val Loss: {val_loss}", f"Val Accuracy: {val_accuracy}")
print(f"Test Loss: {test_loss}", f"Test Accuracy: {test_accuracy}")
# Out:
# Val Loss: 0.22055621445178986 Val Accuracy: 0.9175000190734863
# Test Loss: 0.2142678201198578 Test Accuracy: 0.921500027179718

# %% [markdown]
# ## Model Performance

# %%
y_pred = model.predict(X_test, verbose=0)
y_pred_classes = y_pred.argmax(axis=-1)

classification_rep = classification_report(y_test, y_pred_classes)
accuracy = accuracy_score(y_test, y_pred_classes)

print(accuracy)
print(classification_rep)
# Out:
# 0.9215
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       695
#            1       0.97      0.96      0.96       581
#            2       0.91      0.96      0.93       275
#            3       0.91      0.87      0.89       224
#            4       0.76      0.87      0.81       159
#            5       0.72      0.77      0.74        66
#
#     accuracy                           0.92      2000
#    macro avg       0.87      0.89      0.88      2000
# weighted avg       0.92      0.92      0.92      2000

# %% [markdown]
# ## Embedding Vectors Alteration

# %%
embedding_layer = model.get_layer(name='embedding_layer')

embedding_weights = embedding_layer.get_weights()[0]

word_index = tokenizer.word_index

index_word = {v: k for k, v in word_index.items()}

emotions = ['joy', 'sadness', 'anger', 'fear', 'love', 'surprise', 'happy', 'sad', 'angry', 'fear', 'disgust']

emotion_vectors = {emotion: embedding_weights[word_index[emotion]] for emotion in emotions}

# %%
def plot_emotions(emotion_vectors):
    
    vectors = list(emotion_vectors.values())
    labels = list(emotion_vectors.keys())

    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(vectors)

    plt.figure(figsize=(10, 10))
    for i, label in enumerate(labels):
        plt.scatter(pca_result[i, 0], pca_result[i, 1])
        plt.annotate(label, (pca_result[i, 0], pca_result[i, 1]))
        
    plt.title('Emotion Embeddings PCA')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.grid(True)
    plt.show()


plot_emotions(emotion_vectors)

# %%
def plot_emotions_tsne(emotion_vectors):
    
    vectors = np.array(list(emotion_vectors.values()))
    labels = list(emotion_vectors.keys())

    tsne = TSNE(n_components=2, perplexity=5, random_state=0)
    tsne_result = tsne.fit_transform(vectors)

    plt.figure(figsize=(10, 10))
    for i, label in enumerate(labels):
        plt.scatter(tsne_result[i, 0], tsne_result[i, 1])
        plt.annotate(label, (tsne_result[i, 0], tsne_result[i, 1]))
        
    plt.title('Emotion Embeddings T-SNE')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.grid(True)
    plt.show()


plot_emotions_tsne(emotion_vectors)
